# %% [markdown]
# # Climate Change Indicators Data Analysis

# %% [markdown]
# ## 1.0 Load the Necssary Liberaries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.0 Load Dataset

# %%
# Let df = CC
CC = pd.read_csv ('/kaggle/input/climate-change-indicators/climate_change_indicators.csv')
CC.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
CC.shape
# Out:
# (225, 72)

# %% [markdown]
# ## 2.1 See various columns

# %% [markdown]
# ## 3.0 Clean Dataset

# %% [markdown]
# ### 3.1 Treat Nulls

# %%
CC.isna().sum()
# Out:
# ObjectId      0
# Country       0
# ISO2          2
# ISO3          0
# Indicator     0
#              ..
# F2018        12
# F2019        12
# F2020        13
# F2021        12
# F2022        12
# Length: 72, dtype: int64

# %% [markdown]
# ### 3.2 Show NAN

# %%
NAN = CC[CC.isna().any(axis = 1)]
NAN.isna().sum()
NAN.head(20)
# Out:
#     ObjectId                            Country ISO2 ISO3  \
# 3          4                     American Samoa   AS  ASM
# 7          8                Antigua and Barbuda   AG  ATG
# 9         10                   Armenia, Rep. of   AM  ARM
# 10        11  Aruba, Kingdom of the Netherlands   AW  ABW
# 13        14                Azerbaijan, Rep. of   AZ  AZE
# 17        18                           Barbados   BB  BRB
# 18        19                   Belarus, Rep. of   BY  BLR
# 19        20                            Belgium   BE  BEL
# 24        25             Bosnia and Herzegovina   BA  BIH
# 31        32                            Burundi   BI  BDI
# 32        33                         Cabo Verde   CV  CPV
# 36        37                     Cayman Islands   KY  CYM
# 44        45              Comoros, Union of the   KM  COM
# 46        47                     Congo, Rep. of   CG  COG
# 48        49                         Costa Rica   CR  CRI
# ...

# %% [markdown]
# ### 3.3 Drop NaN

# %%
CC = CC.dropna(axis = 0)

# %%
CC.shape
# Out:
# (156, 72)

# %%
CC.columns
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'F1961', 'F1962',
#        'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970',
#        'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978',
#        'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986',
#        'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994',
#        'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002',
#        'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
#        'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
#        'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %% [markdown]
# ### 3.4 Remove Irrelevant Columns

# %%
CC = CC[[#'ObjectId', 
    'Country', #'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
      # 'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 
    'F1961', 'F1962',
       'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970',
       'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978',
       'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986',
       'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994',
       'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002',
       'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
       'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
       'F2019', 'F2020', 'F2021', 'F2022']].copy()

# %%
CC.head()
# Out:
#                         Country  F1961  F1962  F1963  F1964  F1965  F1966  \
# 0  Afghanistan, Islamic Rep. of -0.113 -0.164  0.847 -0.764 -0.244  0.226
# 1                       Albania  0.627  0.326  0.075 -0.166 -0.388  0.559
# 2                       Algeria  0.164  0.114  0.077  0.250 -0.100  0.433
# 4      Andorra, Principality of  0.736  0.112 -0.752  0.308 -0.490  0.415
# 5                        Angola  0.041 -0.152 -0.190 -0.229 -0.196  0.175
#
#    F1967  F1968  F1969  ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  \
# 0 -0.371 -0.423 -0.539  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910
# 1 -0.074  0.081 -0.013  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675
# 2 -0.026 -0.067  0.291  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115
# 4  0.637  0.018 -0.137  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964
# 5 -0.081 -0.193  0.188  ...  1.044  0.828  1.331  1.609  0.870  1.395  1.752
#
#    F2020  F2021  F2022
# 0  0.498  1.327  2.012
# ...

# %% [markdown]
# ### 3.5 Check Data Types

# %%
CC.dtypes
# Out:
# Country     object
# F1961      float64
# F1962      float64
# F1963      float64
# F1964      float64
#             ...
# F2018      float64
# F2019      float64
# F2020      float64
# F2021      float64
# F2022      float64
# Length: 63, dtype: object

# %% [markdown]
# ### 3.6 Conduct EDA

# %%
CC.describe()
# Out:
#             F1961       F1962       F1963       F1964       F1965       F1966  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean     0.191115   -0.013436   -0.016237   -0.077577   -0.239186    0.130468
# std      0.427485    0.367600    0.411796    0.329208    0.284645    0.402946
# min     -0.694000   -0.908000   -1.270000   -0.877000   -1.064000   -1.801000
# 25%     -0.090500   -0.183250   -0.211000   -0.258000   -0.392500   -0.044500
# 50%      0.070500   -0.070500   -0.042000   -0.052000   -0.220500    0.116000
# 75%      0.361250    0.141500    0.236250    0.132500   -0.077750    0.323750
# max      1.892000    0.998000    1.202000    1.097000    0.857000    1.151000
#
#             F1967       F1968       F1969       F1970  ...       F2013  \
# count  156.000000  156.000000  156.000000  156.000000  ...  156.000000
# mean    -0.102654   -0.201904    0.151449    0.077603  ...    0.889071
# ...

# %% [markdown]
# ### 3.7 Check 'Country' Names

# %%
CC['Country']
# Out:
# 0      Afghanistan, Islamic Rep. of
# 1                           Albania
# 2                           Algeria
# 4          Andorra, Principality of
# 5                            Angola
#                    ...
# 218       Wallis and Futuna Islands
# 219              West Bank and Gaza
# 220                  Western Sahara
# 223                          Zambia
# 224                        Zimbabwe
# Name: Country, Length: 156, dtype: object

# %% [markdown]
# #### Extract just the Country Names without additional info

# %%
CC['Country'] = CC['Country'].apply(lambda x:x.split(',')[0])

# %%
CC.head()
# Out:
#        Country  F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  F1969  \
# 0  Afghanistan -0.113 -0.164  0.847 -0.764 -0.244  0.226 -0.371 -0.423 -0.539
# 1      Albania  0.627  0.326  0.075 -0.166 -0.388  0.559 -0.074  0.081 -0.013
# 2      Algeria  0.164  0.114  0.077  0.250 -0.100  0.433 -0.026 -0.067  0.291
# 4      Andorra  0.736  0.112 -0.752  0.308 -0.490  0.415  0.637  0.018 -0.137
# 5       Angola  0.041 -0.152 -0.190 -0.229 -0.196  0.175 -0.081 -0.193  0.188
#
#    ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 4  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
# 5  ...  1.044  0.828  1.331  1.609  0.870  1.395  1.752  1.162  1.553  1.212
#
# [5 rows x 63 columns]

# %% [markdown]
# ### 3.8 Check for Duplicates

# %%
CC_Dupes =  CC[CC['Country'].duplicated()]
CC_Dupes
# Out:
#     Country  F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  F1969  \
# 41    China  0.055 -0.056  0.330  0.117  0.151  0.652  0.044 -0.654 -0.009
# 42    China  0.259 -0.141  0.289 -0.026  0.078  0.181 -0.282 -0.408 -0.211
# 105   Korea  0.637 -0.094 -0.472  0.608 -0.178  0.099  0.170 -0.678 -0.288
#
#      ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 41   ...  0.763  0.703  1.175  0.770  1.338  1.183  1.776  1.882  2.017  1.432
# 42   ...  1.073  1.062  1.297  1.319  1.573  1.361  1.422  1.620  1.701  1.906
# 105  ...  0.519  0.987  0.944  1.637  1.459  0.966  1.485  1.551  1.762  1.659
#
# [3 rows x 63 columns]

# %% [markdown]
# ### 3.9 Drop Duplicates

# %%
CC = CC.drop_duplicates('Country')

# %%
country_unique = CC['Country'].unique()
country_unique.sort()
country_unique
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Argentina', 'Australia', 'Austria', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Cambodia',
#        'Cameroon', 'Canada', 'Central African Rep.', 'Chad', 'Chile',
#        'China', 'Colombia', 'Congo', 'Cook Islands', 'Cuba', 'Cyprus',
#        'Denmark', 'Dominica', 'Dominican Rep.', 'Ecuador', 'Egypt',
#        'El Salvador', 'Eswatini', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Polynesia', 'Gabon', 'Gambia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Holy See', 'Honduras', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
# ...

# %%
CC.shape
# Out:
# (153, 63)

# %% [markdown]
# ### 3.10 Reset index

# %%
CC = CC.reset_index(drop = True)

# %%
CC.head()
# Out:
#        Country  F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  F1969  \
# 0  Afghanistan -0.113 -0.164  0.847 -0.764 -0.244  0.226 -0.371 -0.423 -0.539
# 1      Albania  0.627  0.326  0.075 -0.166 -0.388  0.559 -0.074  0.081 -0.013
# 2      Algeria  0.164  0.114  0.077  0.250 -0.100  0.433 -0.026 -0.067  0.291
# 3      Andorra  0.736  0.112 -0.752  0.308 -0.490  0.415  0.637  0.018 -0.137
# 4       Angola  0.041 -0.152 -0.190 -0.229 -0.196  0.175 -0.081 -0.193  0.188
#
#    ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
# 4  ...  1.044  0.828  1.331  1.609  0.870  1.395  1.752  1.162  1.553  1.212
#
# [5 rows x 63 columns]

# %% [markdown]
# ## 4. Visualise Data

# %% [markdown]
# ### 4.1 Visualise Data for Nigeria

# %% [markdown]
# #### Extract data for Nigeria

# %%
# Let Nigeria = NG
NG = CC.query("Country =='Nigeria'")
NG
# Out:
#      Country  F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  F1969  \
# 103  Nigeria -0.241 -0.247  0.271 -0.257 -0.037 -0.063 -0.317 -0.035  0.393
#
#      ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 103  ...  0.922  1.012  1.187  1.168   1.17  1.093  1.229  1.127  1.559  0.791
#
# [1 rows x 63 columns]

# %% [markdown]
# #### Plot the 'NG' Data on Graph

# %%
country_of_interest = NG.loc[103] # NG index number = 106

country_name = country_of_interest['Country']
years = country_of_interest.index[1:] # Exclude the 'Country' column
temp = country_of_interest.values[1:] # Exclude the 'Country' column values


plt.figure(figsize = (10,6))
plt.plot(years, temp)

plt.title(f'Average Temperature in {country_name} (1961-2022)')
plt.xlabel('Year')
plt.ylabel('Average Temperature (ᵒC)')
plt.xticks(rotation = 90) # Rotate x-axis ticks by 90 degrees
plt.legend()
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent overlap

# Save figure
plt.savefig('Average_temperature_in_Nigeria(1961-2022).png')
plt.show()

# %% [markdown]
# ### 4.2 Compare Nigeria vs Some Other Countries

# %%
# List of countries to compare
countries_compared = ['Austria', 'Bangladesh', 'Nigeria']

# Filter the dataframe to include only selected countries
CC_compared = CC[CC['Country'].isin(countries_compared)]

# Plot
plt.figure(figsize=(10,6))

for index, row in CC_compared.iterrows():
    country = row['Country']
    years = row.index[1:] # Exclude the 'Country' column
    temp = row.values[1:] # Exclude the 'Country' column values
    plt.plot(years, temp, label= country)

plt.title('Compparison of Average Temperature by Countries (1961-2022)')
plt.xlabel('Year')
plt.ylabel('Average Temperature (ᵒC)')
plt.xticks(rotation = 90) # Rotate x-axis ticks by 90 degrees
plt.legend()
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent overlap

# Save figure
plt.savefig('temperature_comparision_Austria_Bangladesh_Nigeria(1961-2022).png')
plt.show()

# %% [markdown]
# ### 4.3 Checking for Country with the Highest Temperature in a Particular Year

# %%
# Select the column for the year to check
year_to_check = 'F2022' # Can be changed to any other desired year

# Get the index of the country with the highest temperature for the year
country_with_highest_temp = CC.set_index('Country')[year_to_check].idxmax()

# Get the max temp value for the year
highest_temp = CC.set_index('Country')[year_to_check].max()

print(f'The country with the highest temperature in {year_to_check} is {country_with_highest_temp} with a temperature of {highest_temp}C')
# Out:
# The country with the highest temperature in F2022 is Andorra with a temperature of 3.243C

# %% [markdown]
# ### 4.4 Top 10 Countries with Highest Temperatures

# %% [markdown]
# #### See the data

# %%
# Select the column for the year to check
year_to_check = 'F2022' # Can be changed to any other desired year

# Sort the DataFrame by the temp for the selected year in descending order
sorted_CC = CC.sort_values(by = year_to_check, ascending = False)

# Select the top 10 countries with the highest temperatures
top_10_countries = sorted_CC.head(10)
top_10_countries
# Out:
#            Country  F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  \
# 3          Andorra  0.736  0.112 -0.752  0.308 -0.490  0.415  0.637  0.018
# 44          France  0.827 -0.301 -0.955  0.025 -0.625  0.421  0.494 -0.073
# 130    Switzerland  0.988 -0.357 -0.870  0.137 -0.791  0.466  0.554 -0.062
# 92          Monaco  0.739 -0.048 -0.631  0.408 -0.464  0.210  0.432  0.013
# 98     Netherlands  0.852 -0.908 -1.270 -0.337 -0.728  0.273  0.757  0.156
# 48         Germany  0.990 -0.750 -1.084 -0.328 -0.814  0.407  0.868  0.204
# 82   Liechtenstein  1.052 -0.483 -0.775  0.058 -0.840  0.407  0.545  0.013
# 8          Austria  1.031 -0.621 -0.727 -0.371 -0.883  0.602  0.676  0.211
# 124          Spain  0.728  0.411 -0.233  0.486 -0.200  0.392  0.146  0.093
# 99   New Caledonia -0.248  0.081 -0.211  0.164 -0.806 -0.638  0.032 -0.429
#
#      F1969  ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  \
# ...

# %% [markdown]
# #### Top 10 Countries with Highest Temperatures Visualisation

# %%
# Select the column for the year to check
year_to_check = 'F2022' # Can be changed to any other desired year

# Sort the DataFrame by the temp for the selected year in descending order
sorted_CC = CC.sort_values(by = year_to_check, ascending = False)

# Select the top 10 countries with the highest temperatures
top_10_countries = sorted_CC.head(10)

# Plot
plt.figure(figsize=(10,6))
bars = plt.bar(top_10_countries['Country'], top_10_countries[year_to_check], color = 'skyblue')

# Annotate the values on the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 3), ha = 'center', va = 'bottom')

plt.title(f'Top 10 Countries with the Highest Temperature in {year_to_check}')
plt.xlabel('Country')
plt.ylabel('Average Temperature (ᵒC)')
plt.xticks(rotation = 45, ha = 'right') # Rotate x-axis ticks by 90 degrees
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent overlap

# Save figure
plt.savefig('top 10 countries with highest temp in F2022.png')
plt.show()

# %% [markdown]
# ### 4.5 Checking the Behaviour of temperatures in the Top 10 Countries in a Period of 5 Years (2018-2022)

# %%
# Select the years you want to check
years_to_check = ['F2022', 'F2021', 'F2020', 'F2019', 'F2018']  # Change to the desired years

# Sort the DataFrame by the specified years in descending order
sorted_CC = CC.sort_values(by=years_to_check, ascending=False)

# Select the top 10 countries with the highest temperatures
top_10_countries = sorted_CC.head(10)

# Plot
plt.figure(figsize=(12, 8))

# Plot bars for each year for each country
for i, year in enumerate(years_to_check):
    bars = plt.bar([x + i * 0.1 for x in range(len(top_10_countries))],
                   top_10_countries[year],
                   width=0.1,
                   label=year)

    # Annotate the values on the bars
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2), ha='center', va='bottom')

plt.title(f'Top 10 Countries with the Highest Temperatures ({", ".join(years_to_check)})')
plt.xlabel('Country')
plt.ylabel('Average Temperature (°C)')
plt.xticks([r + 0.3 for r in range(len(top_10_countries))], top_10_countries['Country'], rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()

# Save figure
plt.savefig('comparison of top 10 relative to 5 years.png')
plt.show()
